# %%
import pandas as pd

df = pd.read_csv('data/sales_retail_data.csv')
df.head(5)
# Out:
#    Transaction_ID  Customer_ID                 Name                Email  \
# 0       8691788.0      37249.0  Michelle Harrington    Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill     Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen    Shane85@gmail.com
# 3       7232460.0      62101.0        Joseph Miller     Mary34@gmail.com
# 4       4983775.0      27901.0        Debra Coleman  Charles30@gmail.com
#
#           Phone                      Address        City            State  \
# 0  1.414787e+09            3959 Amanda Burgs    Dortmund           Berlin
# 1  6.852900e+09           82072 Dawn Centers  Nottingham          England
# 2  8.362160e+09            4133 Young Canyon     Geelong  New South Wales
# 3  2.776752e+09  8148 Thomas Creek Suite 100    Edmonton          Ontario
# 4  9.098268e+09    5813 Lori Ports Suite 269     Bristol          England
#
#    Zipcode    Country  ...  Total_Amount Product_Category  Product_Brand  \
# ...

# %%
numeric_columns = df.select_dtypes(include=['int64','float64']).columns

print('Analisis de las columnas númericas')

print(df[numeric_columns].describe())
# Out:
# Analisis de las columnas númericas
#        Transaction_ID    Customer_ID         Phone        Zipcode  \
# count    3.016770e+05  301702.000000  3.016480e+05  301670.000000
# mean     5.495823e+06   55006.553934  5.501464e+09   50298.951019
# std      2.595565e+06   26005.675200  2.596017e+09   28972.807134
# min      1.000007e+06   10000.000000  1.000049e+09     501.000000
# 25%      3.247930e+06   32469.250000  3.255061e+09   25425.000000
# 50%      5.499657e+06   55012.000000  5.505812e+09   50602.500000
# 75%      7.739509e+06   77511.000000  7.749860e+09   75252.000000
# max      9.999995e+06   99999.000000  9.999996e+09   99949.000000
#
#                  Age           Year  Total_Purchases         Amount  \
# count  301837.000000  301660.000000    301649.000000  301653.000000
# mean       35.481326    2023.165113         5.359729     255.163659
# std        15.021933       0.371283         2.868575     141.389640
# ...

# %%
#se define variable para la detección de variables numericas
correlation_matrix = df.select_dtypes(include=['int64', 'float64']).columns

#se procede con calcular la matriz de correlación
correlation_matrix = df[numeric_columns].corr(numeric_only=True)
correlation_matrix
# Out:
#                  Transaction_ID  Customer_ID     Phone   Zipcode       Age  \
# Transaction_ID         1.000000     0.004798  0.000515 -0.002964 -0.001630
# Customer_ID            0.004798     1.000000 -0.000966 -0.002478 -0.000162
# Phone                  0.000515    -0.000966  1.000000 -0.003076 -0.003498
# Zipcode               -0.002964    -0.002478 -0.003076  1.000000  0.000278
# Age                   -0.001630    -0.000162 -0.003498  0.000278  1.000000
# Year                  -0.000039     0.000434  0.002556  0.001809 -0.002390
# Total_Purchases       -0.001718     0.003741 -0.000568  0.001293  0.033321
# Amount                -0.003018     0.000342  0.000165  0.001401  0.000846
# Total_Amount          -0.002469     0.002844 -0.000161  0.001407  0.022536
# Ratings               -0.000318     0.001835 -0.000909 -0.002059  0.166999
#
#                      Year  Total_Purchases    Amount  Total_Amount   Ratings
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 10))

sns.heatmap(correlation_matrix, 
            annot=True, 
            cmap='coolwarm', 
            square=True)


plt.title('Grafico No. 8 - Matriz de correlación')
plt.show()

# %%
df2=pd.read_csv('data/Streamed_Spotify_Songs_2024.csv', encoding='Latin-1')
df2
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4595                For the Last Time                 For the Last Time
# 4596                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4597            Grace (feat. 42 Dugg)                           My Turn
# 4598              Nashe Si Chadh Gayi             November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC All Time Rank  Track Score  \
# ...

# %%
numeric_columns = df2.select_dtypes(include=['int64','float64']).columns

print('Analisis de las columnas númericas')

print(df2[numeric_columns].describe())
# Out:
# Analisis de las columnas númericas
#        Track Score  Spotify Popularity  Apple Music Playlist Count  \
# count  4600.000000         3796.000000                  4039.00000
# mean     41.844043           63.501581                    54.60312
# std      38.543766           16.186438                    71.61227
# min      19.400000            1.000000                     1.00000
# 25%      23.300000           61.000000                    10.00000
# 50%      29.900000           67.000000                    28.00000
# 75%      44.425000           73.000000                    70.00000
# max     725.400000           96.000000                   859.00000
#
#        Deezer Playlist Count  Amazon Playlist Count  TIDAL Popularity  \
# count            3679.000000            3545.000000               0.0
# mean               32.310954              25.348942               NaN
# std                54.274538              25.989826               NaN
# ...

# %%
#se define variable para la detección de variables numericas
correlation_matrix = df2.select_dtypes(include=['int64', 'float64']).columns

#se procede con calcular la matriz de correlación
correlation_matrix = df2[numeric_columns].corr(numeric_only=True)
correlation_matrix
# Out:
#                             Track Score  Spotify Popularity  \
# Track Score                    1.000000            0.192808
# Spotify Popularity             0.192808            1.000000
# Apple Music Playlist Count     0.402765            0.288430
# Deezer Playlist Count          0.337561            0.238246
# Amazon Playlist Count          0.548705            0.320260
# TIDAL Popularity                    NaN                 NaN
# Explicit Track                 0.041801            0.073565
#
#                             Apple Music Playlist Count  Deezer Playlist Count  \
# Track Score                                   0.402765               0.337561
# Spotify Popularity                            0.288430               0.238246
# Apple Music Playlist Count                    1.000000               0.775710
# Deezer Playlist Count                         0.775710               1.000000
# Amazon Playlist Count                         0.665635               0.568904
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 10))

sns.heatmap(correlation_matrix, 
            annot=True, 
            cmap='coolwarm', 
            square=True)


plt.title('Grafico No. 8 - Matriz de correlación')
plt.show()
